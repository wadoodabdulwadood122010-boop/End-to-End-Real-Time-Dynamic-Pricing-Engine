# %%
import logging
import pandas as pd
import dagshub
import mlflow
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,  mean_squared_error, r2_score

# %%
## For local use , not for github
mlflow.set_tracking_uri('https://dagshub.com/wadoodabdulwadood122010/End-to-End-Real-Time-Dynamic-Pricing-Engine.mlflow')
dagshub.init(repo_owner='wadoodabdulwadood122010', repo_name='End-to-End-Real-Time-Dynamic-Pricing-Engine', mlflow=True)
mlflow.set_experiment('Final experiment')
# Out:
# Accessing as wadoodabdulwadood122010
# Initialized MLflow to track repo "wadoodabdulwadood122010/End-to-End-Real-Time-Dynamic-Pricing-Engine"
# Repository wadoodabdulwadood122010/End-to-End-Real-Time-Dynamic-Pricing-Engine initialized!
# <Experiment: artifact_location='mlflow-artifacts:/c12f0994ac4c4dd7907ded128067da0f', creation_time=1779967939653, experiment_id='1', last_update_time=1779967939653, lifecycle_stage='active', name='Final experiment', tags={}, trace_location=None, workspace='default'>

# %%
df = pd.read_csv(r'C:\mlops\End-to-End-Real-Time-Dynamic-Pricing-Engine\notebooks\data\processed\processed.csv')

# %%
df  = df.drop(columns = ['Unnamed: 0'])

# %%
df.head()
# Out:
#    Location_Category  Customer_Loyalty_Status  Average_Ratings  \
# 0                  2                        2         0.488713
# 1                  1                        2        -0.452538
# 2                  0                        2        -0.613292
# 3                  0                        1         0.121455
# 4                  0                        1        -1.118630
#
#    Time_of_Booking  Vehicle_Type  Historical_Cost_of_Ride  \
# 0                3             1                -0.471736
# 1                1             0                -1.061811
# 2                0             1                -0.228301
# 3                0             1                 0.522270
# 4                0             0                 1.107522
#
#    Supply-Demand Ratio  Number_of_Past_Rides_Gaussian  \
# 0             0.354130                      -1.096804
# 1             1.098251                       0.574460
# 2             1.363206                      -5.199338
# 3            -0.539825                       0.430727
# 4            -0.708719                       0.635270
#
#    Expected_Ride_Duration_Gaussian  Average_Ratings_Gaussian
# 0                        -0.191052                  0.375793
# 1                        -0.967422                 -0.390065
# 2                        -0.403108                 -0.486994
# 3                         0.515705                  0.077301
# 4                         0.834427                 -0.898304

# %%
x  = df.drop(columns = ['Historical_Cost_of_Ride'])
y = df['Historical_Cost_of_Ride']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
import mlflow
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
estimators = 150
with mlflow.start_run(run_name='Run 2'):
    try:
        print('Logging params ...')
        mlflow.log_params({'test_size': 0.25, 'random_state': 42, 'n_estimators':estimators})

        print('Loading model ...')
        model = RandomForestRegressor()

        print('Training model ...')
        model.fit(x_train, y_train)
        y_pred = model.predict(x_test)

        print('Logging metrics ...')
        # Valid metrics for continuous data
        mse = mean_squared_error(y_test, y_pred)
        r2 = r2_score(y_test, y_pred)
        score = model.score(x_test, y_test)
        
        print(f'   Mean Squared Error: {mse}')
        print(f'   R2 Score: {r2}')
        print(f'   score:', {score})
        
        mlflow.log_metric('mse', mse)
        mlflow.log_metric('r2_score', r2)
        mlflow.log_metric('score', score)


        mlflow.sklearn.log_model(model, name="my_model")
    except Exception as e:
        print(f"An error occurred: {e}")
# Out:
# Logging params ...
# Loading model ...
# Training model ...
# Logging metrics ...
#    Mean Squared Error: 0.15932452089208585
#    R2 Score: 0.8414981994430617
#    score: {0.8414981994430617}
# 2026/05/28 07:44:14 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 🏃 View run Run 2 at: https://dagshub.com/wadoodabdulwadood122010/End-to-End-Real-Time-Dynamic-Pricing-Engine.mlflow/#/experiments/1/runs/782f5d7fea0e45e58a7532fe592b1831
# 🧪 View experiment at: https://dagshub.com/wadoodabdulwadood122010/End-to-End-Real-Time-Dynamic-Pricing-Engine.mlflow/#/experiments/1
